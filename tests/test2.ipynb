# %%
import pandas as pd

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
# !pip install nba_api

# %%
from nba_api.stats.static import players

# get_players returns a list of dictionaries, each representing a player.
nba_players = players.get_players()
print("Number of players fetched: {}".format(len(nba_players)))
pd.DataFrame(nba_players)
# Out:
# Number of players fetched: 4900
#            id            full_name first_name     last_name  is_active
# 0       76001       Alaa Abdelnaby       Alaa     Abdelnaby      False
# 1       76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz      False
# 2       76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar      False
# 3          51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf      False
# 4        1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad      False
# ...       ...                  ...        ...           ...        ...
# 4895  1627790           Ante Zizic       Ante         Zizic      False
# 4896    78647             Jim Zoet        Jim          Zoet      False
# 4897    78648            Bill Zopf       Bill          Zopf      False
# 4898  1627826          Ivica Zubac      Ivica         Zubac       True
# 4899    78650           Matt Zunic       Matt         Zunic      False
#
# [4900 rows x 5 columns]

# %%
from nba_api.stats.static import teams

# get_teams returns a list of 30 dictionaries, each an NBA team.
nba_teams = teams.get_teams()
print("Number of teams fetched: {}".format(len(nba_teams)))
pd.DataFrame(nba_teams)
# Out:
# Number of teams fetched: 30
#             id               full_name abbreviation       nickname  \
# 0   1610612737           Atlanta Hawks          ATL          Hawks
# 1   1610612738          Boston Celtics          BOS        Celtics
# 2   1610612739     Cleveland Cavaliers          CLE      Cavaliers
# 3   1610612740    New Orleans Pelicans          NOP       Pelicans
# 4   1610612741           Chicago Bulls          CHI          Bulls
# 5   1610612742        Dallas Mavericks          DAL      Mavericks
# 6   1610612743          Denver Nuggets          DEN        Nuggets
# 7   1610612744   Golden State Warriors          GSW       Warriors
# 8   1610612745         Houston Rockets          HOU        Rockets
# 9   1610612746    Los Angeles Clippers          LAC       Clippers
# 10  1610612747      Los Angeles Lakers          LAL         Lakers
# 11  1610612748              Miami Heat          MIA           Heat
# 12  1610612749         Milwaukee Bucks          MIL          Bucks
# ...

# %%
spurs = [team for team in nba_teams if team["abbreviation"] == "LAL"][0]
spurs
# Out:
# {'id': 1610612747,
#  'full_name': 'Los Angeles Lakers',
#  'abbreviation': 'LAL',
#  'nickname': 'Lakers',
#  'city': 'Los Angeles',
#  'state': 'California',
#  'year_founded': 1948}

# %%
big_fundamental = [
    player for player in nba_players if player["first_name"] == "LeBron"
][0]
big_fundamental
# Out:
# {'id': 2544,
#  'full_name': 'LeBron James',
#  'first_name': 'LeBron',
#  'last_name': 'James',
#  'is_active': True}

# %%
from nba_api.stats.endpoints import playerprofilev2

player = playerprofilev2.PlayerProfileV2(player_id='2544')

pd.DataFrame(player.get_normalized_dict()['CareerHighs'])
# dict_keys(['resource', 'parameters', 'resultSets'])
# Out:
#     PLAYER_ID     GAME_ID    GAME_DATE  VS_TEAM_ID  VS_TEAM_CITY VS_TEAM_NAME  \
# 0        2544  0021300893  MAR 03 2014  1610612766     Charlotte      Bobcats
# 1        2544  0022300650  JAN 27 2024  1610612744  Golden State     Warriors
# 2        2544  0021201009  MAR 20 2013  1610612739     Cleveland    Cavaliers
# 3        2544  0021100547  MAR 04 2012  1610612747   Los Angeles       Lakers
# 4        2544  0022300650  JAN 27 2024  1610612744  Golden State     Warriors
# 5        2544  0021900613  JAN 15 2020  1610612753       Orlando        Magic
# 6        2544  0021700819  FEB 09 2018  1610612737       Atlanta        Hawks
# 7        2544  0020400303  DEC 13 2004  1610612763       Memphis    Grizzlies
# 8        2544  0020300967  MAR 16 2004  1610612741       Chicago        Bulls
# 9        2544  0020300812  FEB 23 2004  1610612740   New Orleans      Hornets
# 10       2544  0021700122  NOV 03 2017  1610612764    Washington      Wizards
# ...

# %%
from nba_api.stats.endpoints import playercareerstats

career = playercareerstats.PlayerCareerStats(player_id='2544')

career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0        2544   2003-04        00  1610612739               CLE        19.0
# 1        2544   2004-05        00  1610612739               CLE        20.0
# 2        2544   2005-06        00  1610612739               CLE        21.0
# 3        2544   2006-07        00  1610612739               CLE        22.0
# 4        2544   2007-08        00  1610612739               CLE        23.0
# 5        2544   2008-09        00  1610612739               CLE        24.0
# 6        2544   2009-10        00  1610612739               CLE        25.0
# 7        2544   2010-11        00  1610612748               MIA        26.0
# 8        2544   2011-12        00  1610612748               MIA        27.0
# 9        2544   2012-13        00  1610612748               MIA        28.0
# 10       2544   2013-14        00  1610612748               MIA        29.0
# ...

# %%
from nba_api.stats.endpoints import alltimeleadersgrids

alltimeleadersgrids = alltimeleadersgrids.AllTimeLeadersGrids()

alltimeleadersgrids.get_data_frames()[0]
# dict_keys(['GPLeaders', 'PTSLeaders', 'ASTLeaders', 'STLLeaders', 'OREBLeaders', 'DREBLeaders', 'REBLeaders', 'BLKLeaders', 'FGMLeaders', 'FGALeaders', 'FG_PCTLeaders', 'TOVLeaders', 'FG3MLeaders', 'FG3ALeaders', 'FG3_PCTLeaders', 'PFLeaders', 'FTMLeaders', 'FTALeaders', 'FT_PCTLeaders'])
# Out:
#    PLAYER_ID          PLAYER_NAME    GP  GP_RANK IS_ACTIVE_FLAG
# 0        305        Robert Parish  1611        1              N
# 1      76003  Kareem Abdul-Jabbar  1560        2              N
# 2       1713         Vince Carter  1541        3              N
# 3       1717        Dirk Nowitzki  1522        4              N
# 4        304        John Stockton  1504        5              N
# 5       2544         LeBron James  1476        6              Y
# 6        252          Karl Malone  1476        6              N
# 7        708        Kevin Garnett  1462        8              N
# 8        788         Kevin Willis  1424        9              N
# 9       1891          Jason Terry  1410       10              N

# %%
alltimeleadersgrids.get_data_frames()[1]
# Out:
#    PLAYER_ID          PLAYER_NAME    PTS  PTS_RANK IS_ACTIVE_FLAG
# 0       2544         LeBron James  40036         1              Y
# 1      76003  Kareem Abdul-Jabbar  38387         2              N
# 2        252          Karl Malone  36928         3              N
# 3        977          Kobe Bryant  33643         4              N
# 4        893       Michael Jordan  32292         5              N
# 5       1717        Dirk Nowitzki  31560         6              N
# 6      76375     Wilt Chamberlain  31419         7              N
# 7        406     Shaquille O'Neal  28596         8              N
# 8     201142         Kevin Durant  28427         9              Y
# 9       2546      Carmelo Anthony  28289        10              N
